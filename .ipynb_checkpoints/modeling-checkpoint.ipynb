# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import seaborn as sns

# %%
model_df = pd.read_csv('model.csv', index_col='AssignedID')
data = pd.read_csv('data.csv', index_col='AssignedID')

# %%
model_df
# Out:
#             StateCluster_0  StateCluster_2  StateCluster_3  StateCluster_4  \
# AssignedID
# 2131406                  1               0               0               0
# 2131407                  1               0               0               0
# 2131408                  1               0               0               0
# 2131409                  1               0               0               0
# 2131410                  1               0               0               0
# ...                    ...             ...             ...             ...
# 2161350                  1               0               0               0
# 2161351                  1               0               0               0
# 2161352                  1               0               0               0
# 2161353                  1               0               0               0
# 2161354                  1               0               0               0
#
#             StateCluster_5  StateCluster_6  StateCluster_7  MinPer  \
# AssignedID
# 2131406                  0               0               0   29.85
# 2131407                  0               0               0   67.24
# 2131408                  0               0               0   40.76
# 2131409                  0               0               0   75.97
# 2131410                  0               0               0   64.56
# ...                    ...             ...             ...     ...
# 2161350                  0               0               0   22.82
# 2161351                  0               0               0    7.61
# 2161352                  0               0               0    3.69
# 2161353                  0               0               0   10.16
# 2161354                  0               0               0    9.02
#
#             PropType_Dem_PUD  PropType_Hi-Rise_Condo  ...  \
# AssignedID                                            ...
# 2131406                    0                       0  ...
# 2131407                    0                       0  ...
# 2131408                    0                       0  ...
# 2131409                    0                       0  ...
# 2131410                    0                       0  ...
# ...                      ...                     ...  ...
# 2161350                    0                       0  ...
# 2161351                    0                       0  ...
# 2161352                    0                       0  ...
# 2161353                    0                       0  ...
# 2161354                    0                       0  ...
#
#             CoBoCreditScore_Not_Given  CoBoCreditScore_Poor  Term  AmorTerm  \
# AssignedID
# 2131406                             0                     0   360       360
# 2131407                             0                     0   360       360
# 2131408                             0                     0   360       360
# 2131409                             1                     0   360       360
# 2131410                             1                     0   360       360
# ...                               ...                   ...   ...       ...
# 2161350                             0                     0   360       360
# 2161351                             0                     0   180       180
# 2161352                             1                     0   360       360
# 2161353                             0                     0   360       360
# 2161354                             0                     0   240       240
#
#               Rate  Amount   Front    Back  PMI  Purpose
# AssignedID
# 2131406     0.0400  464782  0.2424  0.3221  0.0        1
# 2131407     0.0375  495000  0.2384  0.4550  0.0        1
# 2131408     0.0388  665287  0.1369  0.2102  0.0        2
# 2131409     0.0375  490320  0.2582  0.2951  0.0        1
# 2131410     0.0375   97206  0.4012  0.5304  0.0        1
# ...            ...     ...     ...     ...  ...      ...
# 2161350     0.0525  195865  0.3263  0.4912  0.0        1
# 2161351     0.0438  296000  0.2250  0.3657  0.0        1
# 2161352     0.0475   66400  0.1089  0.2918  0.0        2
# 2161353     0.0500  245600  0.2114  0.2701  0.0        1
# 2161354     0.0463  100000  0.1453  0.4085  0.0        1
#
# [65078 rows x 65 columns]

# %%
import xgboost as xgb
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import confusion_matrix

# %%
model_df.Purpose.value_counts()
# Out:
# 1    42982
# 2    22096
# Name: Purpose, dtype: int64

# %%
# fit a classifier model 
X = model_df.drop(columns=['Purpose'])
y = model_df.Purpose

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size= .30, random_state=31)

clf = xgb.XGBClassifier()
clf.fit(X_train, y_train)
training_preds = clf.predict(X_train)
val_preds = clf.predict(X_test)
training_accuracy = accuracy_score(y_train, training_preds)
val_accuracy = accuracy_score(y_test, val_preds)

print("Training Accuracy: {:.4}%".format(training_accuracy * 100))
print("Validation accuracy: {:.4}%".format(val_accuracy * 100))
# Out:
# Training Accuracy: 79.93%
# Validation accuracy: 79.84%
